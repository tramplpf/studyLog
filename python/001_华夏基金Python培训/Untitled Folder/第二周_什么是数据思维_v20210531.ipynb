# %% [markdown]
# # 《什么是数据思维》笔记
#
# ## 数据分析
#
# ### 数据起源
#
# 数据： 结绳记事
#
#
# 钢丝收银（上世纪九十年代）
#
# 优点：
#  * 点对点
#  * 速度与效率
#
# 缺点：
#  * 实体存储
#  * 所有单据都是纸质单据
#  * 检索比较麻烦
#
#
# 传输--存储--计算
#
#
# 超算中心
#
#
# 由于互联网的存在，数据的存储更加的方便，数据类型也更加丰富。
#
#
# ### 数据分类
#
# 数据类型
#     结构化数据
#         字符串
#     非结构化数据
#         文本，图片，视频，音频
#
# 文本：
#     1> 上市公司公告
#     2>
#
#
#   文本分析的处理过程
#        分词 --> 形成矩阵 --->
#
#
# 卫星灯光
#
#
#
# ### 数据分析
#
# 数据分析的定义：
#
#     数据分析是一个流程
#
#     业务--->转换为数据问题--->收集数据--->数据清洗-->数据探索--->数据建模
#     --->模型优化--->评估
#
#
#     脏数据：
#         数据中有缺省值
#         数据中有异常值
#
#
#     python 在数据分析中的作用：
#         python 在数据分析的整个流程都有体现。
#
#
#      农家乐员工流失？
#
#      员工流失背后的核心是老员工更受老板喜欢。
#         老员工对顾客对农家乐的相关信息了解的更清楚。
#
#
#       点菜--下单--做饭。   一条龙关联起来。 生成了数据。
#       有了数据就便于分析和关联。 得出更多的内容。
#
#
#       python 生态
#       python 在机器学习方面比较擅长
#
#
# #### 数据越多越好么？
# 有代表性的数据是好的。
#
#
# 美国1936年大选
#
#
# 美国飞机改造：

# %% [markdown]
# # 李鹏飞的思考
# 1. 数据的价值
# 2. 如何生成数据，如何让现有的数据有价值
# 3. 如何生成有价值的数据
